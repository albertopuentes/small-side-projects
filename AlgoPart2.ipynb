# %%
# Data manipulation libraries
import pandas as pd
import numpy as np

# Machine learning libraries
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import TimeSeriesSplit
from sklearn.pipeline import Pipeline
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# Technical indicator library
import talib as ta

# Data import library
import yfinance as yf

#Data visualisation
import plotly.graph_objs as go
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-8-8572e196a17a> in <module>
#      13
#      14 # Technical indicator library
# ---> 15 import talib as ta
#      16
#      17 # Data import library
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/talib/__init__.py in <module>
#      91
#      92
# ---> 93 from ._ta_lib import (
#      94     _ta_initialize, _ta_shutdown, MA_Type, __ta_version__,
#      95     _ta_set_unstable_period as set_unstable_period,
#
# ImportError: dlopen(/opt/homebrew/anaconda3/lib/python3.8/site-packages/talib/_ta_lib.cpython-38-darwin.so, 2): Symbol not found: _TA_ACOS
#   Referenced from: /opt/homebrew/anaconda3/lib/python3.8/site-packages/talib/_ta_lib.cpython-38-darwin.so
#   Expected in: flat namespace
#  in /opt/homebrew/anaconda3/lib/python3.8/site-packages/talib/_ta_lib.cpython-38-darwin.so

# %%
df = yf.download('TSLA',period = '1d', interval = '1m')
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                   Open         High          Low        Close  \
# Datetime
# 2021-12-31 09:30:00-05:00  1073.444458  1074.039917  1070.000000  1071.140015
# 2021-12-31 09:31:00-05:00  1070.614990  1078.099976  1070.614990  1076.114746
# 2021-12-31 09:32:00-05:00  1075.683228  1081.999878  1075.683228  1079.015015
# 2021-12-31 09:33:00-05:00  1079.400024  1081.000000  1078.333984  1079.000000
# 2021-12-31 09:34:00-05:00  1078.500122  1080.250000  1077.000000  1079.994263
# ...                                ...          ...          ...          ...
# 2021-12-31 15:55:00-05:00  1055.709961  1056.069946  1055.130005  1055.410034
# 2021-12-31 15:56:00-05:00  1055.489990  1056.319946  1055.319946  1055.939941
# 2021-12-31 15:57:00-05:00  1055.984985  1056.430054  1055.550049  1055.550049
# 2021-12-31 15:58:00-05:00  1055.550049  1056.800049  1054.589966  1056.349976
# 2021-12-31 15:59:00-05:00  1056.349976  1057.239990  1056.069946  1057.239990
#
#                              Adj Close  Volume
# Datetime
# 2021-12-31 09:30:00-05:00  1071.140015  555598
# 2021-12-31 09:31:00-05:00  1076.114746  125213
# 2021-12-31 09:32:00-05:00  1079.015015  166349
# 2021-12-31 09:33:00-05:00  1079.000000   85642
# 2021-12-31 09:34:00-05:00  1079.994263   75711
# ...                                ...     ...
# 2021-12-31 15:55:00-05:00  1055.410034   82972
# 2021-12-31 15:56:00-05:00  1055.939941   91724
# 2021-12-31 15:57:00-05:00  1055.550049  109979
# 2021-12-31 15:58:00-05:00  1056.349976  148699
# 2021-12-31 15:59:00-05:00  1057.239990  189243
#
# [390 rows x 6 columns]

# %% [markdown]
# #### Prepare

# %%
# Drop the rows with zero volume traded
df = df.drop(df[df['Volume'] == 0].index)

# %%
# Create a variable n with a value of 10
n = 10
# Create a column by name, RSI and assign the calculation of RSI to it
df['RSI'] = ta.RSI(np.array(df['Close'].shift(1)), timeperiod=n)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-f805eeff3dfe> in <module>
#       2 n = 10
#       3 # Create a column by name, RSI and assign the calculation of RSI to it
# ----> 4 df['RSI'] = ta.RSI(np.array(df['Close'].shift(1)), timeperiod=n)
#       5 df
#
# NameError: name 'ta' is not defined
